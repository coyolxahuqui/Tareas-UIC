# %% [markdown]
# <a href="https://colab.research.google.com/github/coyolxahuqui/Tareas-UIC/blob/main/S3nolineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datos = pd.read_csv("winequalityN.csv")

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from sklearn import svm

from sklearn.model_selection import train_test_split

# %%
import seaborn as sb
sb.countplot(x="quality", data=datos)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sb.countplot(x="quality", data=datos, hue="type")
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
datos.isna().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
datos = datos.dropna()
#para quitar los que no tienen datos

# %%
datos.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dummies_type = pd.get_dummies(datos["type"], drop_first=True)

# %%
datos = datos.join(dummies_type)

# %%
datos.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality  white
# 0       0.45      8.8        6      1
# 1       0.49      9.5        6      1
# 2       0.44     10.1        6      1
# 3       0.40      9.9        6      1
# 4       0.40      9.9        6      1

# %%
datos = datos.drop(["type"], axis=1)

# %%
datos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  white
# 0      8.8        6      1
# 1      9.5        6      1
# 2     10.1        6      1
# 3      9.9        6      1
# 4      9.9        6      1

# %%
datos.rename(columns={'white': 'Vino'}, inplace=True)

# %%
datos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  Vino
# 0      8.8        6     1
# 1      9.5        6     1
# 2     10.1        6     1
# 3      9.9        6     1
# 4      9.9        6     1

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6463.000000       6463.000000  6463.000000     6463.000000
# mean        7.217755          0.339589     0.318758        5.443958
# std         1.297913          0.164639     0.145252        4.756852
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6463.000000          6463.000000           6463.000000  6463.000000
# mean      0.056056            30.516865            115.694492     0.994698
# std       0.035076            17.758815             56.526736     0.003001
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992330
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.997000
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality         Vino
# count  6463.000000  6463.000000  6463.000000  6463.000000  6463.000000
# mean      3.218332     0.531150    10.492825     5.818505     0.753520
# std       0.160650     0.148913     1.193128     0.873286     0.430995
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     1.000000
# 50%       3.210000     0.510000    10.300000     6.000000     1.000000
# 75%       3.320000     0.600000    11.300000     6.000000     1.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %%
datos.shape
# Out:
# (6463, 13)

# %%
X = datos[['fixed acidity', 'volatile acidity']].values
y = datos['Vino'].values

# %%
sb.scatterplot(x="fixed acidity", y="volatile acidity", data=datos, hue="Vino")
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %%
sb.scatterplot(x="total sulfur dioxide", y="pH", data=datos, hue="Vino")
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='pH'>

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=.2)

# %%
from sklearn import svm
modelo = svm.SVC(kernel='linear')
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)

# %%
modelo_radial = svm.SVC(kernel='rbf')
modelo_radial.fit(X_ent, y_ent)
# Out:
# SVC()

# %%
modelo_poli2 = svm.SVC(kernel='poly', degree=2)
modelo_poli2.fit(X_ent, y_ent)
# Out:
# SVC(degree=2, kernel='poly')

# %%
modelo_poli3 = svm.SVC(kernel='poly', degree=3)
modelo_poli3.fit(X_ent, y_ent)
# Out:
# SVC(kernel='poly')

# %%
modelo_sig = svm.SVC(kernel='sigmoid')
modelo_sig.fit(X_ent, y_ent)
# Out:
# SVC(kernel='sigmoid')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
w = modelo.coef_[0]

b = modelo.intercept_[0]

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1

x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.2), np.arange(x2_min, x2_max, 0.2))

Z = modelo.predict(np.c_[xx1.ravel(), xx2.ravel()])

Z = Z.reshape(xx1.shape)

plt.contourf(xx1, xx2, Z, cmap=plt.cm.coolwarm, alpha=0.3)
plt.scatter(modelo.support_vectors_[:, 0], modelo.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')
x2_decision_boundary = (-w[0] * xx1 - b) / w[1]

plt.plot(xx1, x2_decision_boundary, 'k-')

plt.title('Límite de Decisión SVM')

plt.xlabel('X1')

plt.ylabel('X2')

plt.show()

# %%
x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1

x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.2), np.arange(x2_min, x2_max, 0.2))

Z = modelo.predict(np.c_[xx1.ravel(), xx2.ravel()])

Z = Z.reshape(xx1.shape)

plt.contourf(xx1, xx2, Z, cmap=plt.cm.coolwarm, alpha=0.3)
x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1

x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.2), np.arange(x2_min, x2_max, 0.2))

Z = modelo.predict(np.c_[xx1.ravel(), xx2.ravel()])

Z = Z.reshape(xx1.shape)

plt.contourf(xx1, xx2, Z, cmap=plt.cm.coolwarm, alpha=0.3)

# %%
plt.scatter(modelo.support_vectors_[:, 0], modelo.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')

# %%
x2_decision_boundary = (-w[0] * xx1 - b) / w[1]


plt.plot(xx1, x2_decision_boundary, 'k-')

plt.title('Límite de Decisión SVM')

plt.xlabel('X1')

plt.ylabel('X2')

plt.show()

# %%
h = 0.02

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
Z = modelo.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel('Fixed acidity')

plt.ylabel('Volatile acidity')

plt.title('Límite de decisión SVM lineal')

plt.show()

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1

x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.2), np.arange(x2_min, x2_max, 0.2))

Z = modelo_radial.predict(np.c_[xx1.ravel(), xx2.ravel()])

Z = Z.reshape(xx1.shape)

plt.contourf(xx1, xx2, Z, cmap=plt.cm.coolwarm, alpha=0.3)
plt.scatter(modelo_radial.support_vectors_[:, 0], modelo_radial.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')
x2_decision_boundary = (-w[0] * xx1 - b) / w[1]

plt.plot(xx1, x2_decision_boundary, 'k-')

plt.title('Límite de Decisión SVM-rbf')

plt.xlabel('X1')

plt.ylabel('X2')

plt.show()

# %%
h = 0.02

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
Z = modelo_radial.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel('Fixed acidity')

plt.ylabel('Volatile acidity')

plt.title('Límite de decisión SVM rbf')

plt.show()

# %%
h = 0.02

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
Z = modelo_poli2.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel('Fixed acidity')

plt.ylabel('Volatile acidity')

plt.title('Límite de decisión SVM Polinomial 2')

plt.show()

# %%
h = 0.02

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
Z = modelo_poli3.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel('Fixed acidity')

plt.ylabel('Volatile acidity')

plt.title('Límite de decisión SVM polinomial 3')

plt.show()

# %%
h = 0.02

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
Z = modelo_sig.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel('Fixed acidity')

plt.ylabel('Volatile acidity')

plt.title('Límite de decisión SVM sigmoidal')

plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.8986852281515855

# %%
predicciones = modelo.predict(X_pru)
accuracy_score(y_pru, predicciones)
# Out:
# 0.8986852281515855

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       331
#            1       0.92      0.95      0.93       962
#
#     accuracy                           0.90      1293
#    macro avg       0.88      0.85      0.86      1293
# weighted avg       0.90      0.90      0.90      1293

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pru, predicciones)
# Out:
# array([[241,  65],
#        [ 20, 967]])

# %%
pred_poli2 = modelo_poli2.predict(X_pru)
accuracy_score(y_pru, pred_poli2)
print(classification_report(y_pru, pred_poli2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79       331
#            1       0.91      0.96      0.93       962
#
#     accuracy                           0.90      1293
#    macro avg       0.88      0.85      0.86      1293
# weighted avg       0.90      0.90      0.90      1293

# %%
accuracy_score(y_pru, pred_poli2)
# Out:
# 0.9002320185614849

# %%
pred_poli3 = modelo_poli3.predict(X_pru)
print(classification_report(y_pru, pred_poli3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.73      0.79       331
#            1       0.91      0.96      0.93       962
#
#     accuracy                           0.90      1293
#    macro avg       0.88      0.84      0.86      1293
# weighted avg       0.90      0.90      0.90      1293

# %%
accuracy_score(y_pru, pred_poli3)
# Out:
# 0.8979118329466357

# %%
pred_sig = modelo_sig.predict(X_pru)
print(classification_report(y_pru, pred_sig))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.06      0.07       331
#            1       0.70      0.75      0.72       962
#
#     accuracy                           0.57      1293
#    macro avg       0.39      0.40      0.40      1293
# weighted avg       0.54      0.57      0.55      1293

# %%
accuracy_score(y_pru, pred_sig)
# Out:
# 0.57153905645785

# %%
pred_rad = modelo_radial.predict(X_pru)
print(classification_report(y_pru, pred_rad))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.69      0.77       331
#            1       0.90      0.96      0.93       962
#
#     accuracy                           0.89      1293
#    macro avg       0.88      0.83      0.85      1293
# weighted avg       0.89      0.89      0.89      1293

# %%
accuracy_score(y_pru, pred_rad)
# Out:
# 0.8932714617169374

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index= ["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       241        65
# Real: Si        20       967
