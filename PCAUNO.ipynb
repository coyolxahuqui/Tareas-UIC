# %% [markdown]
# <a href="https://colab.research.google.com/github/coyolxahuqui/Tareas-UIC/blob/main/PCAUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv("winequalityN.csv")

# %%
import seaborn as sb
sb.countplot(x="quality", data=datos)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sb.countplot(x="quality", data=datos, hue="type")
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
datos.isna().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
datos = datos.dropna()

# %%
datos.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dummies_type = pd.get_dummies(datos["type"], drop_first=True)

# %%
datos = datos.join(dummies_type)

# %%
datos.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality  white
# 0       0.45      8.8        6      1
# ...

# %%
datos = datos.drop(["type"], axis=1)

# %%
datos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  white
# 0      8.8        6      1
# 1      9.5        6      1
# ...

# %%
datos.rename(columns={'white': 'Vino'}, inplace=True)

# %%
datos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  Vino
# 0      8.8        6     1
# 1      9.5        6     1
# ...

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6463.000000       6463.000000  6463.000000     6463.000000
# mean        7.217755          0.339589     0.318758        5.443958
# std         1.297913          0.164639     0.145252        4.756852
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6463.000000          6463.000000           6463.000000  6463.000000
# mean      0.056056            30.516865            115.694492     0.994698
# std       0.035076            17.758815             56.526736     0.003001
# ...

# %%
datos.shape
# Out:
# (6463, 13)

# %%
import numpy as np

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X = datos.drop(["Vino"], axis=1)
y = datos["Vino"]

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
print("Estadísticas antes del escalado:")
print("Media:", np.mean(X, axis=0))
print("Desviación estándar:", np.std(X, axis=0))
print("\nEstadísticas después del escalado:")
print("Media:", np.mean(X_scaled, axis=0))
print("Desviación estándar:", np.std(X_scaled, axis=0))
# Out:
# Estadísticas antes del escalado:
# Media: fixed acidity             7.217755
# volatile acidity          0.339589
# citric acid               0.318758
# residual sugar            5.443958
# chlorides                 0.056056
# free sulfur dioxide      30.516865
# total sulfur dioxide    115.694492
# density                   0.994698
# pH                        3.218332
# sulphates                 0.531150
# alcohol                  10.492825
# quality                   5.818505
# dtype: float64
# Desviación estándar: fixed acidity            1.297813
# volatile acidity         0.164627
# citric acid              0.145241
# residual sugar           4.756484
# chlorides                0.035073
# free sulfur dioxide     17.757442
# total sulfur dioxide    56.522363
# density                  0.003001
# pH                       0.160637
# sulphates                0.148902
# alcohol                  1.193036
# quality                  0.873219
# dtype: float64
#
# ...

# %%
X_scaled
# Out:
# array([[-0.16778609, -0.42270958,  0.2839587 , ..., -0.5449872 ,
#         -1.41892232,  0.20784562],
#        [-0.70715516, -0.2404789 ,  0.14625658, ..., -0.27635393,
#         -0.83218392,  0.20784562],
#        [ 0.67979387, -0.36196602,  0.55936296, ..., -0.61214551,
#         -0.32926528,  0.20784562],
#        ...,
#        [-0.70715516,  1.03513588, -1.29961576, ...,  1.46976231,
#          0.42511267,  0.20784562],
#        [-1.01536606,  1.85517396, -1.36846682, ...,  1.20112905,
#         -0.24544551, -0.937343  ],
#        [-0.93831333, -0.17973534,  1.0413204 , ...,  0.86533746,
#          0.42511267,  0.20784562]])

# %%
# Primero se utilizan se reducen a dos componentes

# %%
pc2 = PCA(n_components=2, random_state=42)

# %%
pc_2 = pc2.fit_transform(X_scaled)

# %%
pc_2
# Out:
# array([[ 2.49836923,  3.16466701],
#        [-0.08269753, -0.47392403],
#        [ 0.18303919,  0.29170561],
#        ...,
#        [-2.20830864, -0.65283135],
#        [-2.53751532, -0.21505932],
#        [-1.17991877, -0.62370364]])

# %%
df_2 = pd.DataFrame({'PCA1': pc_2[:,0], 'PCA2': pc_2[:,1], 'Vino': datos['Vino']})

# %%
df_2.head()
# Out:
#        PCA1      PCA2  Vino
# 0  2.498369  3.164667     1
# 1 -0.082698 -0.473924     1
# 2  0.183039  0.291706     1
# 3  1.751396  0.733701     1
# 4  1.751396  0.733701     1

# %%
pc2.explained_variance_ratio_
# Out:
# array([0.2536155 , 0.22076454])

# %%
pc2.explained_variance_ratio_.sum()
# Out:
# 0.4743800427005497

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['PCA1', 'PCA2'], y=pc2.explained_variance_ratio_)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='PCA1', y='PCA2', hue='Vino', data=df_2)
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
# se realiza el mismo procedimiento para 3 componentes

# %%
pc3 = PCA(n_components=3, random_state=42)

# %%
pc_3 = pc3.fit_transform(X_scaled)

# %%
pc_3
# Out:
# array([[ 2.49836923,  3.16466701, -0.10742263],
#        [-0.08269753, -0.47392403, -0.4210178 ],
#        [ 0.18303919,  0.29170561,  0.52759909],
#        ...,
#        [-2.20830864, -0.65283135, -1.29031679],
#        [-2.53751532, -0.21505932, -2.6294559 ],
#        [-1.17991877, -0.62370364,  0.32226459]])

# %%
df_3 = pd.DataFrame({'PCA1': pc_3[:,0], 'PCA2': pc_3[:,1], 'PCA3': pc_3[:,2], 'Vino': datos['Vino']})

# %%
df_3.head()
# Out:
#        PCA1      PCA2      PCA3  Vino
# 0  2.498369  3.164667 -0.107423     1
# 1 -0.082698 -0.473924 -0.421018     1
# 2  0.183039  0.291706  0.527599     1
# 3  1.751396  0.733701 -0.212764     1
# 4  1.751396  0.733701 -0.212764     1

# %%
pc3.explained_variance_ratio_
# Out:
# array([0.2536155 , 0.22076454, 0.13673695])

# %%
pc3.explained_variance_ratio_.sum()
# Out:
# 0.6111169968905725

# %%
sns.barplot(x=['PCA1', 'PCA2', 'PCA3'], y=pc3.explained_variance_ratio_)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='PCA1', y='PCA2', hue='Vino', data=df_3)
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

x = df_3['PCA1']
y = df_3['PCA2']
z = df_3['PCA3']

col = df_3['Vino']

ax.scatter(x,y,z, c=col,  marker='o')

ax.set_xlabel('PCA1')
ax.set_ylabel('PCA2')
ax.set_zlabel('PCA3')

plt.show()

# %%
y = datos["Vino"]

# %%
# comparar los modelos de regresión logística y la reducción de dimensionalidad
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X_scaled, y, test_size=.2)

# %%
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression(max_iter=10000)
modelo.fit(X_ent, y_ent)
# Out:
# LogisticRegression(max_iter=10000)

# %%
predicciones = modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.991492652745553

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       319
#            1       0.99      0.99      0.99       974
#
#     accuracy                           0.99      1293
#    macro avg       0.99      0.99      0.99      1293
# weighted avg       0.99      0.99      0.99      1293

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pru, predicciones)
# Out:
# array([[314,   5],
#        [  6, 968]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index= ["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       314         5
# Real: Si         6       968

# %%
#modelo con dos componentes principales
X = df_2.drop(["Vino"], axis=1)
y = df_2["Vino"]

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=.2)

# %%
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression(max_iter=10000)
modelo.fit(X_ent, y_ent)
# Out:
# LogisticRegression(max_iter=10000)

# %%
predicciones = modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.982985305491106

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       332
#            1       0.99      0.99      0.99       961
#
#     accuracy                           0.98      1293
#    macro avg       0.98      0.98      0.98      1293
# weighted avg       0.98      0.98      0.98      1293

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pru, predicciones)
# Out:
# array([[321,  11],
#        [ 11, 950]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index= ["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       321        11
# Real: Si        11       950

# %%
X = df_2[['PCA1', 'PCA2']].values
y = df_2['Vino'].values

# %%
sb.scatterplot(x="PCA1", y="PCA2", data=df_2, hue="Vino")
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
# prueba con tres componenetes
X = df_3.drop(["Vino"], axis=1)
y = df_3["Vino"]

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=.2)

# %%
from sklearn.linear_model import LogisticRegression
modelo = LogisticRegression(max_iter=10000)
modelo.fit(X_ent, y_ent)
# Out:
# LogisticRegression(max_iter=10000)

# %%
predicciones = modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.9822119102861562

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       329
#            1       0.99      0.98      0.99       964
#
#     accuracy                           0.98      1293
#    macro avg       0.97      0.98      0.98      1293
# weighted avg       0.98      0.98      0.98      1293

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pru, predicciones)
# Out:
# array([[321,   8],
#        [ 15, 949]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index= ["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       321         8
# Real: Si        15       949

# %%
# probar un algoritmo svm
X = df_2[['PCA1', 'PCA2']].values
y = df_2['Vino'].values

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=.2)

# %%
from sklearn import svm
modelo = svm.SVC(kernel='linear')
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
w = modelo.coef_[0]

b = modelo.intercept_[0]

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1

x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.2), np.arange(x2_min, x2_max, 0.2))

Z = modelo.predict(np.c_[xx1.ravel(), xx2.ravel()])

Z = Z.reshape(xx1.shape)

plt.contourf(xx1, xx2, Z, cmap=plt.cm.coolwarm, alpha=0.3)
plt.scatter(modelo.support_vectors_[:, 0], modelo.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')
x2_decision_boundary = (-w[0] * xx1 - b) / w[1]

plt.plot(xx1, x2_decision_boundary, 'k-')

plt.title('Límite de Decisión SVM')

plt.xlabel('X1')

plt.ylabel('X2')

plt.show()

# %%
h = 0.02

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
Z = modelo.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, cmap=plt.cm.Paired)
plt.xlabel('PCA1')

plt.ylabel('PCA2')

plt.title('Límite de decisión SVM lineal')

plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.9837587006960556

# %%
predicciones = modelo.predict(X_pru)
accuracy_score(y_pru, predicciones)
# Out:
# 0.9837587006960556

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       322
#            1       0.99      0.99      0.99       971
#
#     accuracy                           0.98      1293
#    macro avg       0.98      0.98      0.98      1293
# weighted avg       0.98      0.98      0.98      1293
