# %% [markdown]
# <a href="https://colab.research.google.com/github/coyolxahuqui/Tareas-UIC/blob/main/ArbolesDecisionS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datos = pd.read_csv("winequalityN.csv")

# %%
datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
datos.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
import seaborn as sb
sb.countplot(x="quality", data=datos)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sb.countplot(x="quality", data=datos, hue="type")
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sb.displot(x="pH", data=datos, hue="type")

# %%
datos.isna()
#Para ver si hay datos vacios
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 6492  False          False             False        False           False
# 6493  False          False             False        False           False
# 6494  False          False             False        False           False
# 6495  False          False             False        False           False
# 6496  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# 0         False                False                 False    False  False
# 1         False                False                 False    False  False
# 2         False                False                 False    False  False
# 3         False                False                 False    False  False
# 4         False                False                 False    False  False
# ...         ...                  ...                   ...      ...    ...
# 6492      False                False                 False    False  False
# 6493      False                False                 False    False  False
# 6494      False                False                 False    False  False
# 6495      False                False                 False    False  False
# 6496      False                False                 False    False  False
#
#       sulphates  alcohol  quality
# 0         False    False    False
# 1         False    False    False
# 2         False    False    False
# 3         False    False    False
# 4         False    False    False
# ...         ...      ...      ...
# 6492      False    False    False
# 6493       True    False    False
# 6494      False    False    False
# 6495      False    False    False
# 6496      False    False    False
#
# [6497 rows x 13 columns]

# %%
datos.isna().sum()
#conteo de datos vacios
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
datos = datos.dropna()
#para quitar los que no tienen datos

# %%
datos.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
datos.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <ipython-input-12-4301f4327c1a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# <Axes: >

# %%
dummies_type = pd.get_dummies(datos["type"], drop_first=True)

# %%
datos = datos.join(dummies_type)

# %%
datos.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality  white
# 0       0.45      8.8        6      1
# 1       0.49      9.5        6      1
# 2       0.44     10.1        6      1
# 3       0.40      9.9        6      1
# 4       0.40      9.9        6      1

# %%
datos = datos.drop(["type"], axis=1)

# %%
datos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  white
# 0      8.8        6      1
# 1      9.5        6      1
# 2     10.1        6      1
# 3      9.9        6      1
# 4      9.9        6      1

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
datos.rename(columns={'white': 'Vino'}, inplace=True)

# %%
datos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  Vino
# 0      8.8        6     1
# 1      9.5        6     1
# 2     10.1        6     1
# 3      9.9        6     1
# 4      9.9        6     1

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
X = datos.drop(["Vino"], axis=1)
y = datos["Vino"]

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=.2)

# %%
from sklearn.tree import DecisionTreeClassifier
modelo = DecisionTreeClassifier(max_depth=10)
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.9907192575406032

# %%
from sklearn.tree import DecisionTreeClassifier

resultados = []
for i in range(1,20):
  modelo = DecisionTreeClassifier(max_depth=i)
  modelo.fit(X_ent, y_ent)
  predicciones = modelo.predict(X_pru)
  exactitud = accuracy_score(y_pru, predicciones)
  print(f"Exactitud para {i}: {exactitud}")
  resultados.append(exactitud)
# Out:
# Exactitud para 1: 0.925754060324826
# Exactitud para 2: 0.9659706109822119
# Exactitud para 3: 0.9760247486465584
# Exactitud para 4: 0.9860788863109049
# Exactitud para 5: 0.988399071925754
# Exactitud para 6: 0.9907192575406032
# Exactitud para 7: 0.9907192575406032
# Exactitud para 8: 0.9907192575406032
# Exactitud para 9: 0.9907192575406032
# Exactitud para 10: 0.9907192575406032
# Exactitud para 11: 0.9899458623356535
# Exactitud para 12: 0.9899458623356535
# Exactitud para 13: 0.9907192575406032
# Exactitud para 14: 0.9876256767208044
# Exactitud para 15: 0.9899458623356535
# Exactitud para 16: 0.9907192575406032
# Exactitud para 17: 0.988399071925754
# Exactitud para 18: 0.9907192575406032
# Exactitud para 19: 0.9899458623356535

# %%
sb.lineplot(data=resultados)
#al parecer con 6 es suficiente
# Out:
# <Axes: >

# %%
modelo = DecisionTreeClassifier(max_depth=6)
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)
exactitud = accuracy_score(y_pru, predicciones)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       302
#            1       0.99      1.00      0.99       991
#
#     accuracy                           0.99      1293
#    macro avg       0.99      0.98      0.99      1293
# weighted avg       0.99      0.99      0.99      1293

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pru, predicciones)
# Out:
# array([[291,  11],
#        [  2, 989]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index= ["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       291        11
# Real: Si         2       989

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(100, 80))
plot_tree( modelo, feature_names=X_ent.columns, class_names=["Blanco", "Tinto"],
filled=True, label="none")
# Out:
# [Text(0.46511627906976744, 0.9285714285714286, 'total sulfur dioxide <= 67.5\n0.375\n5170\n[1291, 3879]\nTinto'),
#  Text(0.22674418604651161, 0.7857142857142857, 'chlorides <= 0.046\n0.184\n1143\n[1026, 117]\nBlanco'),
#  Text(0.12790697674418605, 0.6428571428571429, 'sulphates <= 0.555\n0.236\n117\n[16, 101]\nTinto'),
#  Text(0.046511627906976744, 0.5, 'volatile acidity <= 0.655\n0.045\n87\n[2, 85]\nTinto'),
#  Text(0.023255813953488372, 0.35714285714285715, '0.0\n83\n[0, 83]\nTinto'),
#  Text(0.06976744186046512, 0.35714285714285715, 'citric acid <= 0.085\n0.5\n4\n[2, 2]\nBlanco'),
#  Text(0.046511627906976744, 0.21428571428571427, '0.0\n2\n[2, 0]\nBlanco'),
#  Text(0.09302325581395349, 0.21428571428571427, '0.0\n2\n[0, 2]\nTinto'),
#  Text(0.20930232558139536, 0.5, 'chlorides <= 0.037\n0.498\n30\n[14, 16]\nTinto'),
#  Text(0.16279069767441862, 0.35714285714285715, 'total sulfur dioxide <= 45.0\n0.133\n14\n[1, 13]\nTinto'),
#  Text(0.13953488372093023, 0.21428571428571427, '0.0\n1\n[1, 0]\nBlanco'),
#  Text(0.18604651162790697, 0.21428571428571427, '0.0\n13\n[0, 13]\nTinto'),
#  Text(0.2558139534883721, 0.35714285714285715, 'alcohol <= 10.6\n0.305\n16\n[13, 3]\nBlanco'),
#  Text(0.23255813953488372, 0.21428571428571427, '0.0\n3\n[0, 3]\nTinto'),
#  Text(0.27906976744186046, 0.21428571428571427, '0.0\n13\n[13, 0]\nBlanco'),
#  Text(0.32558139534883723, 0.6428571428571429, 'sulphates <= 0.365\n0.031\n1026\n[1010, 16]\nBlanco'),
#  Text(0.3023255813953488, 0.5, '0.0\n5\n[0, 5]\nTinto'),
#  Text(0.3488372093023256, 0.5, 'residual sugar <= 1.1\n0.021\n1021\n[1010, 11]\nBlanco'),
#  Text(0.32558139534883723, 0.35714285714285715, '0.0\n2\n[0, 2]\nTinto'),
#  Text(0.37209302325581395, 0.35714285714285715, 'residual sugar <= 11.7\n0.018\n1019\n[1010, 9]\nBlanco'),
#  Text(0.32558139534883723, 0.21428571428571427, 'density <= 0.991\n0.014\n1016\n[1009, 7]\nBlanco'),
#  Text(0.3023255813953488, 0.07142857142857142, '0.0\n1\n[0, 1]\nTinto'),
#  Text(0.3488372093023256, 0.07142857142857142, '0.012\n1015\n[1009, 6]\nBlanco'),
#  Text(0.4186046511627907, 0.21428571428571427, 'sulphates <= 0.53\n0.444\n3\n[1, 2]\nTinto'),
#  Text(0.3953488372093023, 0.07142857142857142, '0.0\n2\n[0, 2]\nTinto'),
#  Text(0.4418604651162791, 0.07142857142857142, '0.0\n1\n[1, 0]\nBlanco'),
#  Text(0.7034883720930233, 0.7857142857142857, 'chlorides <= 0.069\n0.123\n4027\n[265, 3762]\nTinto'),
#  Text(0.6046511627906976, 0.6428571428571429, 'sulphates <= 1.115\n0.021\n3631\n[39, 3592]\nTinto'),
#  Text(0.5813953488372093, 0.5, 'volatile acidity <= 0.797\n0.02\n3628\n[36, 3592]\nTinto'),
#  Text(0.5348837209302325, 0.35714285714285715, 'pH <= 3.835\n0.016\n3616\n[30, 3586]\nTinto'),
#  Text(0.5116279069767442, 0.21428571428571427, 'chlorides <= 0.013\n0.016\n3615\n[29, 3586]\nTinto'),
#  Text(0.4883720930232558, 0.07142857142857142, '0.5\n4\n[2, 2]\nBlanco'),
#  Text(0.5348837209302325, 0.07142857142857142, '0.015\n3611\n[27, 3584]\nTinto'),
#  Text(0.5581395348837209, 0.21428571428571427, '0.0\n1\n[1, 0]\nBlanco'),
#  Text(0.627906976744186, 0.35714285714285715, 'fixed acidity <= 5.95\n0.5\n12\n[6, 6]\nBlanco'),
#  Text(0.6046511627906976, 0.21428571428571427, '0.0\n6\n[6, 0]\nBlanco'),
#  Text(0.6511627906976745, 0.21428571428571427, '0.0\n6\n[0, 6]\nTinto'),
#  Text(0.627906976744186, 0.5, '0.0\n3\n[3, 0]\nBlanco'),
#  Text(0.8023255813953488, 0.6428571428571429, 'density <= 0.995\n0.49\n396\n[226, 170]\nBlanco'),
#  Text(0.6976744186046512, 0.5, 'citric acid <= 0.06\n0.118\n111\n[7, 104]\nTinto'),
#  Text(0.6744186046511628, 0.35714285714285715, '0.0\n3\n[3, 0]\nBlanco'),
#  Text(0.7209302325581395, 0.35714285714285715, 'chlorides <= 0.071\n0.071\n108\n[4, 104]\nTinto'),
#  Text(0.6976744186046512, 0.21428571428571427, '0.0\n2\n[2, 0]\nBlanco'),
#  Text(0.7441860465116279, 0.21428571428571427, 'fixed acidity <= 9.95\n0.037\n106\n[2, 104]\nTinto'),
#  Text(0.7209302325581395, 0.07142857142857142, '0.019\n105\n[1, 104]\nTinto'),
#  Text(0.7674418604651163, 0.07142857142857142, '0.0\n1\n[1, 0]\nBlanco'),
#  Text(0.9069767441860465, 0.5, 'residual sugar <= 8.2\n0.356\n285\n[219, 66]\nBlanco'),
#  Text(0.8604651162790697, 0.35714285714285715, 'total sulfur dioxide <= 158.5\n0.115\n228\n[214, 14]\nBlanco'),
#  Text(0.8372093023255814, 0.21428571428571427, 'volatile acidity <= 0.3\n0.027\n217\n[214, 3]\nBlanco'),
#  Text(0.813953488372093, 0.07142857142857142, '0.375\n4\n[1, 3]\nTinto'),
#  Text(0.8604651162790697, 0.07142857142857142, '0.0\n213\n[213, 0]\nBlanco'),
#  Text(0.8837209302325582, 0.21428571428571427, '0.0\n11\n[0, 11]\nTinto'),
#  Text(0.9534883720930233, 0.35714285714285715, 'fixed acidity <= 8.95\n0.16\n57\n[5, 52]\nTinto'),
#  Text(0.9302325581395349, 0.21428571428571427, 'pH <= 3.43\n0.071\n54\n[2, 52]\nTinto'),
#  Text(0.9069767441860465, 0.07142857142857142, '0.037\n53\n[1, 52]\nTinto'),
#  Text(0.9534883720930233, 0.07142857142857142, '0.0\n1\n[1, 0]\nBlanco'),
#  Text(0.9767441860465116, 0.21428571428571427, '0.0\n3\n[3, 0]\nBlanco')]

# %%
predicciones = modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.9837587006960556

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       309
#            1       0.99      0.99      0.99       984
#
#     accuracy                           0.98      1293
#    macro avg       0.98      0.98      0.98      1293
# weighted avg       0.98      0.98      0.98      1293

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pru, predicciones)
# Out:
# array([[297,  12],
#        [  9, 975]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index= ["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       297        12
# Real: Si         9       975

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
VinoX = [7.0, 0.27, 0.38, 15, 0.05, 20, 150, 1, 3.1, .45, 8.7, 6]

# %%
prediccion = modelo.predict([VinoX])
if prediccion[0] == 1:
  print("Blanco")
else:
  print("Rojo")
# Out:
# Blanco
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
